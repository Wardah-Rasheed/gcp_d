# %%
# %pip list
# Out:
# Package                               Version
# ------------------------------------- ---------
# aiohttp                               3.8.1
# aiosignal                             1.2.0
# ansiwrap                              0.8.4
# anyio                                 3.5.0
# appdirs                               1.4.4
# argon2-cffi                           21.3.0
# argon2-cffi-bindings                  21.2.0
# arrow                                 1.2.2
# asn1crypto                            1.5.1
# async-timeout                         4.0.2
# asynctest                             0.13.0
# attrs                                 21.4.0
# Babel                                 2.9.1
# backcall                              0.2.0
# backports.functools-lru-cache         1.6.4
# beatrix-jupyterlab                    3.1.7
# beautifulsoup4                        4.10.0
# binaryornot                           0.4.4
# black                                 22.1.0
# ...

# %%
import pandas as pd

# %%
import numpy as np

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_15536/3793406994.py in <module>
# ----> 1 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
pip install tensorflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.5/497.5 MB 2.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 KB 75.9 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.7/126.7 KB 479.4 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 12.3 MB/s eta 0:00:00:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 7.3 MB/s eta 0:00:000:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 KB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 69.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 73.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 102.2 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 KB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 99.9 MB/s eta 0:00:00:00:01
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("WHO-COVID-19-global-table-data.csv")

# %%
df.head()
# Out:
#                                      Name  WHO Region  \
# Global                                NaN   494587638
# United States of America         Americas    79544396
# India                     South-East Asia    43033067
# Brazil                           Americas    30067249
# France                             Europe    25781400
#
#                           Cases - cumulative total  \
# Global                                 6345.308578
# United States of America              24031.347000
# India                                  3118.328000
# Brazil                                14145.338000
# France                                39639.690000
#
#                           Cases - cumulative total per 100000 population  \
# Global                                                           7708594
# United States of America                                          201598
# India                                                               7292
# ...

# %%
df.describe()
# Out:
#          WHO Region  Cases - cumulative total  \
# count  2.380000e+02                237.000000
# mean   4.156199e+06              14239.327973
# std    3.268375e+07              14832.231130
# min    0.000000e+00                  0.000000
# 25%    1.726025e+04               1185.208000
# 50%    1.594295e+05               9524.915000
# 75%    9.817270e+05              23655.755000
# max    4.945876e+08              70926.021000
#
#        Cases - cumulative total per 100000 population  \
# count                                    2.380000e+02
# mean                                     6.477810e+04
# std                                      5.198390e+05
# min                                     -7.000000e+00
# 25%                                      2.675000e+01
# 50%                                      3.080000e+02
# 75%                                      4.759250e+03
# max                                      7.708594e+06
#
#        Cases - newly reported in last 7 days  \
# ...
